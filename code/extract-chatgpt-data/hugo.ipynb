# %%
import pandas as pd

df = pd.read_json('conversations.json')
filter_hugo = df.title.apply(lambda x: 'Hugo' in x)
df = df[filter_hugo]
df.title = df.title.apply(lambda x: x.split()[0])
df
# Out:
#      title                   create_time                   update_time  \
# 1     Hugo 2024-02-22 12:35:28.412269115 2024-02-22 12:38:07.749278069
# 6    Sarah 2024-02-08 18:28:06.511363028 2024-02-08 18:46:13.235078096
# 7   Thomas 2024-02-08 18:14:28.059876919 2024-02-08 18:25:08.498577118
# 8    Chloé 2024-02-08 18:08:08.074573040 2024-02-08 18:09:59.683222055
# 9    Naomi 2024-02-08 11:05:12.371021032 2024-02-08 12:49:16.883585930
# 10  Yannis 2024-02-08 10:51:41.232528925 2024-02-08 10:59:32.806504011
# 11  Nathan 2024-02-08 10:37:08.087573051 2024-02-08 10:40:02.069571972
#
#                                               mapping moderation_results  \
# 1   {'9caac3b3-6dc8-4202-9c30-3440493b1630': {'id'...                 []
# 6   {'c1a5df26-ab55-474a-9824-86235384af12': {'id'...                 []
# 7   {'7a53dc8d-8b15-4af7-beef-c4d2e257ef61': {'id'...                 []
# 8   {'83c75163-06e7-4f03-8fc4-27b68ca2d4dd': {'id'...                 []
# 9   {'d5499e81-fc15-43c1-9a6e-50c05da8eed7': {'id'...                 []
# 10  {'d072e956-60c8-4c10-83b1-744ce1df8e33': {'id'...                 []
# 11  {'ee1a9976-10cf-443a-9697-298ed7c97e8c': {'id'...                 []
#
#                             current_node  plugin_ids  \
# 1   ab9f4796-292b-4542-a9d5-b2d052f9ae1a         NaN
# 6   6241eddc-42e5-4f49-ac64-b5e14e440826         NaN
# 7   bb7a059c-b347-42f8-b087-40e785bde18d         NaN
# 8   b8f4f7e6-fa7e-41f0-ad0a-0b72e7aa9924         NaN
# 9   061f4924-6173-4411-94c4-e6719de6363f         NaN
# 10  3454a3d6-a55d-4894-8075-c2cd939db516         NaN
# 11  464255aa-ebe6-42f4-904b-6e4dbcfa230b         NaN
#
#                          conversation_id conversation_template_id  \
# 1   66d31fda-ad30-43b0-aa8b-27820b092b9a              g-7szvKTFWO
# 6   c8e8c0b2-55f1-42a0-a60b-5bb442b3a37c              g-7szvKTFWO
# 7   c1f805c1-fb86-48dd-a350-31585d5b85f3              g-7szvKTFWO
# 8   bb46b1fa-a730-4bd0-9c0d-0cda33c7b03a              g-7szvKTFWO
# 9   056a9529-394f-4778-878f-743a7edafff9              g-7szvKTFWO
# 10  550309ab-fb52-4fc4-ae9d-62ca6d02b0f0              g-7szvKTFWO
# 11  ca452c35-61bd-4112-a739-80683e265abb              g-7szvKTFWO
#
#        gizmo_id  is_archived safe_urls                                    id
# 1   g-7szvKTFWO        False        []  66d31fda-ad30-43b0-aa8b-27820b092b9a
# 6   g-7szvKTFWO        False        []  c8e8c0b2-55f1-42a0-a60b-5bb442b3a37c
# 7   g-7szvKTFWO        False        []  c1f805c1-fb86-48dd-a350-31585d5b85f3
# 8   g-7szvKTFWO        False        []  bb46b1fa-a730-4bd0-9c0d-0cda33c7b03a
# 9   g-7szvKTFWO        False        []  056a9529-394f-4778-878f-743a7edafff9
# 10  g-7szvKTFWO        False        []  550309ab-fb52-4fc4-ae9d-62ca6d02b0f0
# 11  g-7szvKTFWO        False        []  ca452c35-61bd-4112-a739-80683e265abb

# %%
import os

conversations = []
for index, conv in df.iterrows():
    keys = list(conv.mapping.keys())
    instance = f"## Conversation de {conv.title} avec Doctor Hugo\n"
    for key in keys[3:]:
        role = conv.mapping[key]['message']['author']['role']
        role = 'Doctor Hugo' if role == 'assistant' else conv.title
        instance += f"### {role}  \n"
        instance += f"{conv.mapping[key]['message']['content']['parts'][0]}  \n"
        instance += "\n"
    conversations.append(instance)

directory = 'convs'
if not os.path.exists(directory):
    os.makedirs(directory)

for i, conv in enumerate(conversations):
    with open(f'convs/conv_{i}.md', 'a') as f:
        f.write(conv)
